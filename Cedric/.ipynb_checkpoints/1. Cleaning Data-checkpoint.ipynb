# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading Data

# %%
brew = pd.read_csv('../data/breweryinfo.csv')
brew.head()
# Out:
#   beer_ratings beer_reviews  beer_score  beers            brewery_name  \
# 0            8            3        3.39      6               'A Magara
# 1        2,969          517        3.84     48   (512) Brewing Company
# 2          176           74        3.65     19       't Hofbrouwerijke
# 3            1            1        3.30      1                 0,5 Pub
# 4            1            0        4.72      5  0 Mile Brewing Company
#
#    brewery_number brewery_pdev brewery_ratings  brewery_review brewery_score  \
# 0           40282          NaN             NaN             NaN           NaN
# 1           17863          0%                2             0.0        4.02/5
# 2           13160          NaN             NaN             NaN           NaN
# 3           53883          0%                0             0.0           0/5
# 4           42171          NaN             NaN             NaN           NaN
#
#               city        country      province
# 0  Nocera Terinese          Italy           NaN
# 1           Austin  United States         Texas
# 2          Beerzel        Belgium           NaN
# 3            Cahul        Moldova           NaN
# 4      Hummelstown  United States  Pennsylvania

# %% [markdown]
# #### Let's remove the '%' and '/5' from brewery_pdev and brewery_score

# %%
brew['brewery_pdev'] = pd.to_numeric(brew['brewery_pdev'].str.replace('%', ''))

# %%
brew['brewery_score'] = pd.to_numeric(brew['brewery_score'].str.replace('/5', ''))

# %%
brew.head()
# Out:
#   beer_ratings beer_reviews  beer_score  beers            brewery_name  \
# 0            8            3        3.39      6               'A Magara
# 1        2,969          517        3.84     48   (512) Brewing Company
# 2          176           74        3.65     19       't Hofbrouwerijke
# 3            1            1        3.30      1                 0,5 Pub
# 4            1            0        4.72      5  0 Mile Brewing Company
#
#    brewery_number  brewery_pdev brewery_ratings  brewery_review  \
# 0           40282           NaN             NaN             NaN
# 1           17863           0.0               2             0.0
# 2           13160           NaN             NaN             NaN
# 3           53883           0.0               0             0.0
# 4           42171           NaN             NaN             NaN
#
#    brewery_score             city        country      province
# 0            NaN  Nocera Terinese          Italy           NaN
# 1           4.02           Austin  United States         Texas
# 2            NaN          Beerzel        Belgium           NaN
# 3           0.00            Cahul        Moldova           NaN
# 4            NaN      Hummelstown  United States  Pennsylvania

# %%
beer = pd.read_csv('../data/beerinfo.csv')
beer.head()
# Out:
# C:\Users\wangz\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    abv  availability  ba_score beer_name beer_number brewery_name  \
# 0  NaN           NaN      0.00    Trilla      172737    'A Magara
# 1  NaN           NaN      4.14   Trupija      172735    'A Magara
# 2  NaN           NaN      2.80     Riulì      273357    'A Magara
# 3  NaN           NaN      3.57  Mericana      318408    'A Magara
# 4  NaN           NaN      3.41   Magarìa      249754    'A Magara
#
#   brewery_number  notes pdev ranking ratings reviews                    style
# 0          40282    NaN  0%        -       0       0        German Hefeweizen
# 1          40282    NaN  0%        -       1       0           Belgian Saison
# 2          40282    NaN  0%        -       2       1  American Pale Ale (APA)
# 3          40282    NaN  0%        -       1       0             American IPA
# 4          40282    NaN  0%        -       2       1          American Porter

# %% [markdown]
# Reading the beer csv file prompted an error on two beers that were not parsed by the spider properly. The first one is [Weird Beard / Farmageddon Suspect Device](https://www.beeradvocate.com/beer/profile/31624/228703/) and the second one is [Interboro / Pipeworks - Mad Fat! Unicorn](https://www.beeradvocate.com/beer/profile/44293/272459/). I have no idea the scraper failed on those two, but we have to move on with our lives. We have to remove those entries.

# %%
beer = beer[pd.to_numeric(beer['brewery_number'], errors='coerce').notnull()]
beer['brewery_number'] = pd.to_numeric(beer['brewery_number'])
beer.shape
# Out:
# (274223, 13)

# %%
comments = pd.read_csv('../data/comment.csv')
# Out:
# C:\Users\wangz\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
comments.head()
# Out:
#    ba_score beer_number                                            comment  \
# 0      4.14      172735                                                NaN
# 1      2.83      273357  Dark amber, very hazy, with some small pieces ...
# 2      3.57      318408                                                NaN
# 3      3.02      249754  Black, light brown foam.<br>\nIn the smell coc...
# 4      3.55      380750                                                NaN
#
#            date  feel  look  overall rdev  smell  taste    username
# 0  Dec 24, 2017   NaN   NaN      NaN  NaN    NaN    NaN  Nattesferd
# 1  Mar 22, 2017   NaN   NaN      NaN  NaN    NaN    NaN     stcules
# 2  Dec 24, 2017   NaN   NaN      NaN  NaN    NaN    NaN  Nattesferd
# 3  Sep 21, 2016   NaN   NaN      NaN  NaN    NaN    NaN     stcules
# 4  Nov 12, 2018   NaN   NaN      NaN  NaN    NaN    NaN      desint

# %%
comments.shape
# Out:
# (2404130, 11)

# %% [markdown]
# Similarly, we'd have to remove comment entries for those two beers

# %%
comments = comments[pd.to_numeric(comments['beer_number'], errors='coerce').notnull()]
comments['beer_number'] = pd.to_numeric(comments['beer_number'])

# %%
comments.shape
# Out:
# (2422451, 11)

# %%
beer = beer[pd.to_numeric(beer['beer_number'], errors='coerce').notnull()]
beer['beer_number'] = pd.to_numeric(beer['beer_number'])

# %% [markdown]
# ## Taking a look at comment data

# %%
comments['comment'].iloc[3]
# Out:
# 'Black, light brown foam.<br>\nIn the smell cocoa, toasted, chocolate. Dusty.<br>\nSame notes in the taste.<br>\nQuite round body, not excessive.<br>\nOk, nohing to remember, but an honest, drinkable, right to the styel robust porter.<br>\nThe 8ABV are well perceptible.<br><br><i class="fas fa-align-left"></i>\xa0<span class="muted">244 characters</span><br><br>'

# %% [markdown]
# #### There are evidently still some html tags left in the comments. We shell remove that

# %%
comments['comment'] = comments['comment'].str.replace('<[^>]*>',' ')
comments['comment'] = comments['comment'].str.replace('\\n',' ')
comments['comment'] = comments['comment'].str.replace('(\\xa0.*characters)',' ')

# %%
comments['comment'].iloc[3]
# Out:
# 'Black, light brown foam.  In the smell cocoa, toasted, chocolate. Dusty.  Same notes in the taste.  Quite round body, not excessive.  Ok, nohing to remember, but an honest, drinkable, right to the styel robust porter.  The 8ABV are well perceptible.        '

# %% [markdown]
# ### Saving data as one SQL database

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///beeradvocate.db')

# %%
brew.to_sql('breweries', con = engine)
beer.to_sql('beers', con = engine)
comments.to_sql('reviews', con = engine)

# %% [markdown]
# ## Subsetting data to Canadian only

# %%
can_brew = brew[brew['country'] == 'Canada']
can_brew.head()
# Out:
#     beer_ratings beer_reviews  beer_score  beers              brewery_name  \
# 32             0            0        0.00      3        13 Barrels Brewing
# 70            81           25        3.98     31       2 Crows Brewing Co.
# 126          271           75        3.86     99     5 Paddles Brewing Co.
# 135           15           14        3.53     12  4th Meridian Brewing Co.
# 176            6            0        4.31     10     9 Mile Legacy Brewing
#
#      brewery_number  brewery_pdev brewery_ratings  brewery_review  \
# 32            56604          0.00               0             0.0
# 70            48315          0.00               1             0.0
# 126           32116          9.51              12             2.0
# 135           47607           NaN             NaN             NaN
# 176           52744          0.00               1             1.0
#
#      brewery_score          city country       province
# 32            0.00      Bathurst  Canada  New Brunswick
# 70            4.04       Halifax  Canada    Nova Scotia
# 126           4.31        Whitby  Canada        Ontario
# 135            NaN  Lloydminster  Canada        Alberta
# 176           4.75     Saskatoon  Canada   Saskatchewan

# %%
can_beer = beer[beer['brewery_number'].isin(can_brew['brewery_number'])]
can_beer.head()
# Out:
#      abv  availability  ba_score                 beer_name  beer_number  \
# 41   NaN           NaN      0.00                Tall Tales       425476
# 42   NaN           NaN      0.00               Rendez-Vous       425481
# 44   NaN           NaN      0.00                  Pabineau       425475
# 407  NaN           NaN      4.30            STAND UP BROWN       344989
# 408  NaN           NaN      4.24  SINGLE HOP SERIES ENIGMA       347006
#
#               brewery_name  brewery_number  notes pdev ranking ratings  \
# 41      13 Barrels Brewing           56604    NaN  0%        -       0
# 42      13 Barrels Brewing           56604    NaN  0%        -       0
# 44      13 Barrels Brewing           56604    NaN  0%        -       0
# 407  9 Mile Legacy Brewing           52744    NaN  0%        -       1
# 408  9 Mile Legacy Brewing           52744    NaN  0%        -       1
#
#     reviews                     style
# 41        0              American IPA
# 42        0  American Amber / Red Ale
# 44        0   American Pale Ale (APA)
# 407       0        American Brown Ale
# 408       0          English Pale Ale

# %%
can_reviews = comments[comments['beer_number'].isin(can_beer['beer_number'])]
can_reviews.head()
# Out:
#      ba_score  beer_number comment          date  feel  look  overall rdev  \
# 787      4.30       344989     NaN  May 13, 2018   NaN   NaN      NaN  NaN
# 788      4.24       347006     NaN  May 22, 2018   NaN   NaN      NaN  NaN
# 789      4.24       345724     NaN  May 11, 2019   NaN   NaN      NaN  NaN
# 790      4.43       371424     NaN  Sep 21, 2018   NaN   NaN      NaN  NaN
# 791      4.49       371425     NaN  Sep 21, 2018   NaN   NaN      NaN  NaN
#
#      smell  taste      username
# 787    NaN    NaN  LocalBeerGuy
# 788    NaN    NaN  LocalBeerGuy
# 789    NaN    NaN  LocalBeerGuy
# 790    NaN    NaN  LocalBeerGuy
# 791    NaN    NaN  LocalBeerGuy

# %% [markdown]
# ### Save these files as csv for furthur analysis

# %%
can_brew.to_csv("../data/CanadianBreweries.csv")
can_beer.to_csv("../data/CanadianBeers.csv")
can_reviews.to_csv("../data/CanadianReviews.csv")
